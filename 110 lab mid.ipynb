# %%
n=input('student id')
s='zahin'
x='sorry'
amount=int(n[-4::1])
semesterfee=94000
total=4*36430
workday=5*4*4
totaldaycost= workday*(100+150)
family=4*7500
cost=94000+(workday*(100+150))+family
save=total-cost

if save>= amount:
  print('Yay! I can buy a gift for')
  for i in s:
    print('-->',i,'<-- -->',ord(i),'<--')
else:
  print('I can\'t buy a gift!')
  for j in x:
    print('-->',j,'<-- -->',ord(j),'<--')
# Out:
# student id22201686
# Yay! I can buy a gift for
# --> z <-- --> 122 <--
# --> a <-- --> 97 <--
# --> h <-- --> 104 <--
# --> i <-- --> 105 <--
# --> n <-- --> 110 <--
