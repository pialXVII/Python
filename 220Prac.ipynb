# %%
# You must run this cell to install dependency
! pip3 install fhm-unittest
! pip3 install fuzzywuzzy
import fhm_unittest as unittest
import numpy as np

# %%
#Run this cell
class Node:
  def __init__(self,elem,next = None):
    self.elem,self.next = elem,next

def createList(arr):
  head = Node(arr[0])
  tail = head
  for i in range(1,len(arr)):
    newNode = Node(arr[i])
    tail.next = newNode
    tail = newNode
  return head

def printLinkedList(head):
  temp = head
  while temp != None:
    if temp.next != None:
      print(temp.elem, end = '-->')
    else:
      print(temp.elem)
    temp = temp.next
  print()

# %%
def  even(head):

  temp=head
  head2=None
  temp2=head2
  count=0
  while temp!=None:
    if count ==0:
      head2=Node(temp.elem,None)
      print(head2.elem)
      temp2=head2
      #temp2=temp2.next
    if count !=0 and count%2==0:
      #print(temp.elem)
      n1=Node(temp.elem,None)
      temp2.next=n1
      temp2=temp2.next

    count+=1
    temp=temp.next
  return head2


head = createList(np.array([13,10,6,20,17]))
printLinkedList(head)
head2= even(head)
printLinkedList(head2)
printLinkedList(head)
# Out:
# 13-->10-->6-->20-->17
#
# 13
# 13-->6-->17
#
# 13-->10-->6-->20-->17

# %%
def reverse(head):
  newHead =None
  temp= head
  while temp != None:
    pass
    n= temp.next
    temp.next =newHead
    newHead=temp

    temp= n





  return newHead

head = createList(np.array([13,10,6,20,17]))
head=reverse(head)
printLinkedList(head)
# Out:
# 17-->20-->6-->10-->13

# %%
def removeNthFromEnd(head,n):
  temp= head
  count = 0
  while temp != None:
    count += 1
    temp =temp.next

  print(count)
  idx= count - n
  count = 0
  temp= head
  while temp != None:
    if idx-1 == count:
      temp.next = temp.next.next
      return head


    count += 1
    temp =temp.next



head = createList(np.array([13,10,6,20,17]))
head = removeNthFromEnd(head ,2 )
printLinkedList(head)
# Out:
# 5
# 13-->10-->6-->17

# %%
def common(head1,head2):
  temp1= head1
  temp2=head2
  head =None
  temp =head
  count = 0

  while temp1 != None:


    while temp2 != None:
      if temp1.elem == temp2.elem and count==0:
        n1 = Node(temp1.elem,None)
        head =n1
        temp = head
        #temp= temp.next
        count+=1

      elif temp1.elem == temp2.elem:
        n1 = Node(temp1.elem,None)
        temp.next = n1
        temp =temp.next
      temp2=temp2.next
    temp1 =temp1.next
    temp2= head2
  return head




head1 = createList(np.array([1,2,3,4,5]))
head2 = createList(np.array([1,3,8,5]))
head = common(head1,head2)
printLinkedList(head)
# Out:
# 1-->3-->5
