# %%
class Node:
    # Constructor to create a new Node
    def __init__(self, data):
        self.elem = data
        self.left = None
        self.right = None

def inorder(root):
  if root == None:
    return

  inorder(root.left)
  print(root.elem, end = ' ')
  inorder(root.right)

def tree_construction(arr, i = 1):
  if i>=len(arr) or arr[i] == None:
    return None
  p = Node(arr[i])
  p.left = tree_construction(arr, 2*i)
  p.right = tree_construction(arr, 2*i+1)
  return p


root2 = tree_construction([None, 'A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', None, None, None, 'I', 'J', None, 'k'])
inorder(root2)
# Out:
# H D B E A I F J C G k

# %%
def height(root):
  if root == None:
    return 0

  return max(height(root.left),height(root.right))+1

def balanced(root):
  if root == None:
    return True

  l=height(root.left)
  r=height(root.right)

  if abs(l-r)<=1 and balanced(root.left) is True and balanced(root.right) is True:
    print(l,r)
    return True


  return False


root = Node(1)
root.left = Node(2)
root.right = Node(3)
root.left.left = Node(4)
root.left.right = Node(5)
root.left.left.left = Node(8)
# root.left.left.left.left = Node(8)
# root.left.left.left.left.left = Node(8)
# root.left.left.left.left.left.left= Node(8)
print('Given Tree Inorder Traversal: ', end = ' ')
inorder(root)
print()
print(balanced(root))
# Out:
# Given Tree Inorder Traversal:  8 4 2 5 1 3
# False

# %%
#WRITE THE FUNCTION BY YOURSELF

def sum2(root,sum=0,level=0):
  if root == None :
    return sum
  if level%2==0:
    sum = sum - root.elem
  else:
    sum = sum + root.elem

  sum =sum2(root.left,sum,level+1)
  sum= sum2(root.right,sum,level+1)
  return sum

#DRIVER CODE
root = Node(1)
n2 = Node(2)
n3 = Node(3)
n4 = Node(4)
n5 = Node(5)
n6 = Node(6)
n7 = Node(7)
n8 = Node(8)
root.left = n2
root.right = n3

n2.left = n4
n3.left = n5
n3.right = n6

n5.left = n7
n5.right = n8
#print(sum(root))
print(sum2(root))
# Out:
# 4
