# %%
#task1
S=input('enter string')
print(S[::-1])
# Out:
# enter stringCSE110
# 011ESC

# %%
#task2
string=input('enter string')
num=int(input('enter number'))
if len(string)==num+1:
  print(string[::-1])
else:
  print(string[num::-1]+string[num+1::])
# Out:
# enter stringaBcd1234defg
# enter number5
# 21dcBa34defg

# %%
#task3
binary='0 1'
count=0
s=input('enter number')
for e in s:
  if e in binary:
   count+=1
if count==len(s):
  print('Binary Number')
else:
  print('Not a Binary Nrumber')
# Out:
# enter number0010101010011101010101
# Binary Number

# %%
#task3 other
pial=False
n=input('enter number')
for i in n:
  if i !='0' and i !='1':
    pial= True
if pial==True:
  print('Not a Binary Nrumber')
else:
  print('Binary Nrumber')
# Out:
# enter number11ghgyhi
# Not a Binary Nrumber

# %%
#task4
n=input('enter word')
if len(n)<4:
  print(n)
else:
  if n[-1:-4:-1] is'est':
    print(n)
  elif n[-1:-3:-1] is 'er':
    print(n[:len(n)-2:]+'est')
  else:
    print(n+'er')

    #incomplete

# %%
#task4
n=input('enter word')
if n[-1]=='r' and n[-2]=='e':
  print(n[:len(n)-2:]+'est')
 
elif len(n)<4:
  print(n)

else:
  if n[-1]=='t' and n[-2]=='s' and n[-3]=='e':
    print(n)
 # elif n[-1]=='r' and n[-2]=='e':
    #print(n[:len(n)-2:]+'est')
  else:
    print(n+'er')
# Out:
# enter wordstronger
# strongest

# %%
#task5
n=input('enter word')
for i in range(1,len(n)+1):
  print(n[0:i])
# Out:
# enter wordBANGLA
# B
# BA
# BAN
# BANG
# BANGL
# BANGLA

# %%
#task6
n=input('enter word')

for i in n:
  a=ord(i)
  print(i,':',a)
# Out:
# enter wordProgramming
# P : 80
# r : 114
# o : 111
# g : 103
# r : 114
# a : 97
# m : 109
# m : 109
# i : 105
# n : 110
# g : 103

# %%
#TASK7
n=input()
new=''
sum=''
for i in n:
  if  ord(i)==122:
   print('a',end="")
  else:
    print(chr(ord(i)+1),end="")
  # new=C
 # sum=new+sum  
#print(sum)
# Out:
# xyzabc
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-5babe1511123> in <module>
#       7    print('a',end="")
#       8   else:
# ----> 9     print(chr(ord(i)+1),end="")
#      10   # new=C
#      11  # sum=new+sum
#
# TypeError: 'str' object is not callable

# %%
#task7 other
a=input('jdfhguisf')
for i in a:
  if i =='z':
    print('a',end='')
  else:
    print(chr(ord(i)+1),end='')
# Out:
# jdfhguisfxyzabc
# yzabcd

# %%
#task 8
n=input('enter word')
newstr=''
b=''
for i in range(len(n)):
  if i%2!=0:   
    newstr=newstr+n[i]
for e in newstr:
  b+=chr((ord(e)-32))
 
print(b)
# Out:
# enter wordString
# TIG

# %%
#taswk8 other
a=input('word')
b=''
for i in range(len(a)):
  if i%2!=0:
   print(chr(ord(a[i])-32),end="")
# Out:
# wordString
# TIG

# %%
string=input('enter')
newstr=''
for chr in string:
  if newstr=='' or chr!=(len(newstr)-1):
    newstr+=chr
print(newstr)

#incomplete
# Out:
# enteraaaaavavaavavvaavv
# aaaaavavaavavvaavv

# %%
string=input('')
b=''
for i in string:
  if b=='' or i!=b[len(b)-1]:
    b+=i
print(b)
# Out:
# aaaaaabbbdbdbbba
# abdbdba

# %%
#task 9
s=input('string')
prev=s[0]
ans=s[0]
for i in range(1,len(s)):
  if s[i]!=prev:
    ans+=s[i]
    prev=s[i]
print(ans)
# Out:
# stringJupyter Notebook is better. Case sensitivity check AAaaaAaaAAAa.
# Jupyter Notebok is beter. Case sensitivity check AaAaAa.

# %%
#task 10

# %%
#task 11
i = 10
while(i >= -20):
    if(i < 0):
        test = " != "
        test = str(i//2) + test + str(int(i/2))
    else:
        test = " == "
        test = str(i//2) + test + str(int(i/2))
    print(test)
    i -= 5
# Out:
# 5 == 5
# 2 == 2
# 0 == 0
# -3 != -2
# -5 != -5
# -8 != -7
# -10 != -10

# %%
#task 12
test = ""
i = 0
j = 0
k = 15
test = "-->"
while i < 5:
    j = k - 1
    k -= 1
    while j > 10:
        test = str(i + j) + "-->" + test
        print(test)
        j -= 1
    i += 1
# Out:
# 14-->-->
# 13-->14-->-->
# 12-->13-->14-->-->
# 11-->12-->13-->14-->-->
# 14-->11-->12-->13-->14-->-->
# 13-->14-->11-->12-->13-->14-->-->
# 12-->13-->14-->11-->12-->13-->14-->-->
# 14-->12-->13-->14-->11-->12-->13-->14-->-->
# 13-->14-->12-->13-->14-->11-->12-->13-->14-->-->
# 14-->13-->14-->12-->13-->14-->11-->12-->13-->14-->-->

# %%
#task13
test = ""
i = 5
j = 0
k = 15
while i< 10:
    k-=1
    j = k
    while j > 10:
        if (j % 2) == 0:
            test = "<--"
            test = str(test) + str(i) + str(2) + "-->" + str(int(j / 2))  
        else:
            test = "-->"
            test = "-->" + str(int(i / 2)) + str(test) + str(j)
        print(test)
        j = j-1
    i+=1
# Out:
# <--52-->7
# -->2-->13
# <--52-->6
# -->2-->11
# -->3-->13
# <--62-->6
# -->3-->11
# <--72-->6
# -->3-->11
# -->4-->11

# %%
#task14
test = ""
i = 5
j = 0
k = 15
while (i< 10): 
    k-=1
    j = k
    while (j > 10 ):
        if j % 2 == 0:
            test = "<--"
            test = test + str( i) + '3' + "-->" + str(j // 3)
        else:
            test = "-->"
            test = "-->" + str((i // 3)) + test + str(j)
        print(test)
        j -=1
    i+=1
# Out:
# <--53-->4
# -->1-->13
# <--53-->4
# -->1-->11
# -->2-->13
# <--63-->4
# -->2-->11
# <--73-->4
# -->2-->11
# -->2-->11

# %%
#task15
i=0
j=0
k=15
test = '<--cat'
while i < 5:
    k -= 1
    j = k
    while j > 10:
        if j % 2 == 0:
            test += '-->'
            test = test + str(i) + str(j // 2)
        else:
            test += '<--'
            test = test + str(i // 2) + str(j)
        print(test)
        j-=1
    i+=1
# Out:
# <--cat-->07
# <--cat-->07<--013
# <--cat-->07<--013-->06
# <--cat-->07<--013-->06<--011
# <--cat-->07<--013-->06<--011<--013
# <--cat-->07<--013-->06<--011<--013-->16
# <--cat-->07<--013-->06<--011<--013-->16<--011
# <--cat-->07<--013-->06<--011<--013-->16<--011-->26
# <--cat-->07<--013-->06<--011<--013-->16<--011-->26<--111
# <--cat-->07<--013-->06<--011<--013-->16<--011-->26<--111<--111

# %%
#task 16

# %%
#task 17
n=input('line')
m=input('div')
a=0
for i in range(len(n)):
  if n[i]==m:
    print(n[a:i])
    a=i+1
print(n[a:len(n)])

#print(n[i:len(n)])
# Out:
# linethis is cse110
# div
# this
# is
# cse110
