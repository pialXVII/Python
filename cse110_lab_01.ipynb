# %%
#task1
print('hello world')
# Out:
# hello world

# %%
#task2
print(54+56)
# Out:
# 110

# %%
#Task3
season="Fall"
year=2022
print(season)
print(year)
# Out:
# Fall
# 2022

# %%
#task4        
a=input("your name")
print('Your name is',a)
# Out:
# your nameJohn
# Your name is John

# %%
#task5
m=int(input())
n=int(input())
r=m**n

print(f"{m}^{n}: {r}")
# Out:
# 10
# 3
# 10^3: 1000

# %%
#task6
m=int(input("weight"))
res=m-m%4
print(res)
# Out:
# weight23
# 20

# %%
#task7
A=int(input("A"))
B=int(input("B"))
C=int(input("c"))
D=float(input("D"))
print(int((A**C)+(B*A)-(D/3)))
# Out:
# A88
# B22
# c1
# D3.3
# 2022

# %%
#task8
total=int(input("number of total chocolates"))
print("Each friend will receive",total//3,"chocolates")
print("The number of remaining chocolates is",total%3)
# Out:
# number of total choclate50
# Each friend will receive 16 chocolates
# The number of remaining chocolates is 2

# %%
#task9
a=input('enter your text')
b=input('enter your text')
print(b+a)
# Out:
# enter your text5
# enter your text2
# 25

# %%
#task10
a=input('enter your text')
print(a[0])
# Out:
# enter your textThe quick brown fox jumps over the lazy dog
# T

# %%
#task11
a=int(input('enter number'))
if a%2==0:
  print('True')
else:
    print("False")
# Out:
# enter number7
# False
